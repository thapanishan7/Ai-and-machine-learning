# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)

# %%
from PIL import Image
image_colored = Image.open("/content/drive/MyDrive/AI & Machine learning /download.jpg")

# %%
print("format:", image_colored.format)
print("size:", image_colored.size)
print("mode:", image_colored.mode)
# Out:
# format: JPEG
# size: (238, 148)
# mode: RGB

# %%
image_colored = image_colored.convert("RGB")
print(image_colored.mode)
# Out:
# RGB

# %%
image_grayed = image_colored.convert("L")
display(image_grayed)
# Out:
# <PIL.Image.Image image mode=L size=238x148>

# %%
width,height = image_grayed.size
channels= len(image_grayed.getbands())
print(f"Image shape (gray): ({height},{width},{channels})")
image_size_grayed = width * height *1
print(f"Image size (gray): {image_size_grayed}")
# Out:
# Image shape (gray): (148,238,1)
# Image size (gray): 35224

# %%
width,height = image_colored.size
channels= len(image_colored.getbands())
print(f"Image shape (gray): ({height},{width},{channels})")
image_size_grayed = width * height * 3
print(f"Image size (gray): {image_size_grayed}")
# Out:
# Image shape (gray): (148,238,3)
# Image size (gray): 105672

# %%
import numpy as np
image_array_colored = np.array(image_colored)
image_array_colored.shape
# Out:
# (148, 238, 3)

# %%
red_channel = image_array_colored [: , : , 0]
print(red_channel)
display(red_channel)
# Out:
# [[ 50  50  50 ...  82  81  81]
#  [ 50  50  50 ...  82  82  82]
#  [ 50  50  50 ...  83  83  83]
#  ...
#  [212 212 211 ... 220 221 221]
#  [212 212 211 ... 222 223 223]
#  [212 212 211 ... 224 225 225]]
# array([[ 50,  50,  50, ...,  82,  81,  81],
#        [ 50,  50,  50, ...,  82,  82,  82],
#        [ 50,  50,  50, ...,  83,  83,  83],
#        ...,
#        [212, 212, 211, ..., 220, 221, 221],
#        [212, 212, 211, ..., 222, 223, 223],
#        [212, 212, 211, ..., 224, 225, 225]], dtype=uint8)

# %%
red_channel = image_array_colored.copy()
red_channel [: , : , 1]=0
red_channel [: , : , 2]=0
print( red_channel)
display( red_channel)
# Out:
# [[[ 50   0   0]
#   [ 50   0   0]
#   [ 50   0   0]
#   ...
#   [ 82   0   0]
#   [ 81   0   0]
#   [ 81   0   0]]
#
#  [[ 50   0   0]
#   [ 50   0   0]
#   [ 50   0   0]
#   ...
#   [ 82   0   0]
#   [ 82   0   0]
#   [ 82   0   0]]
#
#  [[ 50   0   0]
#   [ 50   0   0]
#   [ 50   0   0]
#   ...
#   [ 83   0   0]
#   [ 83   0   0]
#   [ 83   0   0]]
#
#  ...
#
#  [[212   0   0]
#   [212   0   0]
#   [211   0   0]
#   ...
#   [220   0   0]
#   [221   0   0]
#   [221   0   0]]
#
#  [[212   0   0]
#   [212   0   0]
#   [211   0   0]
#   ...
#   [222   0   0]
#   [223   0   0]
#   [223   0   0]]
#
#  [[212   0   0]
#   [212   0   0]
#   [211   0   0]
#   ...
#   [224   0   0]
#   [225   0   0]
#   [225   0   0]]]
# array([[[ 50,   0,   0],
#         [ 50,   0,   0],
#         [ 50,   0,   0],
#         ...,
#         [ 82,   0,   0],
#         [ 81,   0,   0],
#         [ 81,   0,   0]],
#
#        [[ 50,   0,   0],
#         [ 50,   0,   0],
#         [ 50,   0,   0],
#         ...,
#         [ 82,   0,   0],
#         [ 82,   0,   0],
#         [ 82,   0,   0]],
#
#        [[ 50,   0,   0],
#         [ 50,   0,   0],
#         [ 50,   0,   0],
#         ...,
#         [ 83,   0,   0],
#         [ 83,   0,   0],
#         [ 83,   0,   0]],
#
#        ...,
#
#        [[212,   0,   0],
#         [212,   0,   0],
#         [211,   0,   0],
#         ...,
#         [220,   0,   0],
#         [221,   0,   0],
#         [221,   0,   0]],
#
#        [[212,   0,   0],
#         [212,   0,   0],
#         [211,   0,   0],
#         ...,
#         [222,   0,   0],
#         [223,   0,   0],
#         [223,   0,   0]],
#
#        [[212,   0,   0],
#         [212,   0,   0],
#         [211,   0,   0],
#         ...,
#         [224,   0,   0],
#         [225,   0,   0],
#         [225,   0,   0]]], dtype=uint8)

# %%
green_channel = image_array_colored.copy()
green_channel [: , : , 0]=0
green_channel [: , : , 2]=0
print( green_channel)
display( green_channel)
# Out:
# [[[  0  80   0]
#   [  0  80   0]
#   [  0  80   0]
#   ...
#   [  0 136   0]
#   [  0 135   0]
#   [  0 135   0]]
#
#  [[  0  80   0]
#   [  0  80   0]
#   [  0  80   0]
#   ...
#   [  0 136   0]
#   [  0 136   0]
#   [  0 136   0]]
#
#  [[  0  80   0]
#   [  0  80   0]
#   [  0  80   0]
#   ...
#   [  0 137   0]
#   [  0 137   0]
#   [  0 137   0]]
#
#  ...
#
#  [[  0 219   0]
#   [  0 219   0]
#   [  0 218   0]
#   ...
#   [  0 230   0]
#   [  0 231   0]
#   [  0 231   0]]
#
#  [[  0 219   0]
#   [  0 219   0]
#   [  0 218   0]
#   ...
#   [  0 232   0]
#   [  0 233   0]
#   [  0 233   0]]
#
#  [[  0 219   0]
#   [  0 219   0]
#   [  0 218   0]
#   ...
#   [  0 234   0]
#   [  0 235   0]
#   [  0 235   0]]]
# array([[[  0,  80,   0],
#         [  0,  80,   0],
#         [  0,  80,   0],
#         ...,
#         [  0, 136,   0],
#         [  0, 135,   0],
#         [  0, 135,   0]],
#
#        [[  0,  80,   0],
#         [  0,  80,   0],
#         [  0,  80,   0],
#         ...,
#         [  0, 136,   0],
#         [  0, 136,   0],
#         [  0, 136,   0]],
#
#        [[  0,  80,   0],
#         [  0,  80,   0],
#         [  0,  80,   0],
#         ...,
#         [  0, 137,   0],
#         [  0, 137,   0],
#         [  0, 137,   0]],
#
#        ...,
#
#        [[  0, 219,   0],
#         [  0, 219,   0],
#         [  0, 218,   0],
#         ...,
#         [  0, 230,   0],
#         [  0, 231,   0],
#         [  0, 231,   0]],
#
#        [[  0, 219,   0],
#         [  0, 219,   0],
#         [  0, 218,   0],
#         ...,
#         [  0, 232,   0],
#         [  0, 233,   0],
#         [  0, 233,   0]],
#
#        [[  0, 219,   0],
#         [  0, 219,   0],
#         [  0, 218,   0],
#         ...,
#         [  0, 234,   0],
#         [  0, 235,   0],
#         [  0, 235,   0]]], dtype=uint8)

# %%
blue_channel = image_array_colored.copy()
blue_channel [: , : , 0]=0
blue_channel [: , : , 1]=0
print( blue_channel)
display( blue_channel)
# Out:
# [[[  0   0  10]
#   [  0   0  10]
#   [  0   0  10]
#   ...
#   [  0   0  40]
#   [  0   0  39]
#   [  0   0  39]]
#
#  [[  0   0  10]
#   [  0   0  10]
#   [  0   0  10]
#   ...
#   [  0   0  40]
#   [  0   0  40]
#   [  0   0  40]]
#
#  [[  0   0  10]
#   [  0   0  10]
#   [  0   0  10]
#   ...
#   [  0   0  41]
#   [  0   0  41]
#   [  0   0  41]]
#
#  ...
#
#  [[  0   0 229]
#   [  0   0 229]
#   [  0   0 228]
#   ...
#   [  0   0 239]
#   [  0   0 240]
#   [  0   0 240]]
#
#  [[  0   0 229]
#   [  0   0 229]
#   [  0   0 228]
#   ...
#   [  0   0 241]
#   [  0   0 242]
#   [  0   0 242]]
#
#  [[  0   0 229]
#   [  0   0 229]
#   [  0   0 228]
#   ...
#   [  0   0 243]
#   [  0   0 244]
#   [  0   0 244]]]
# array([[[  0,   0,  10],
#         [  0,   0,  10],
#         [  0,   0,  10],
#         ...,
#         [  0,   0,  40],
#         [  0,   0,  39],
#         [  0,   0,  39]],
#
#        [[  0,   0,  10],
#         [  0,   0,  10],
#         [  0,   0,  10],
#         ...,
#         [  0,   0,  40],
#         [  0,   0,  40],
#         [  0,   0,  40]],
#
#        [[  0,   0,  10],
#         [  0,   0,  10],
#         [  0,   0,  10],
#         ...,
#         [  0,   0,  41],
#         [  0,   0,  41],
#         [  0,   0,  41]],
#
#        ...,
#
#        [[  0,   0, 229],
#         [  0,   0, 229],
#         [  0,   0, 228],
#         ...,
#         [  0,   0, 239],
#         [  0,   0, 240],
#         [  0,   0, 240]],
#
#        [[  0,   0, 229],
#         [  0,   0, 229],
#         [  0,   0, 228],
#         ...,
#         [  0,   0, 241],
#         [  0,   0, 242],
#         [  0,   0, 242]],
#
#        [[  0,   0, 229],
#         [  0,   0, 229],
#         [  0,   0, 228],
#         ...,
#         [  0,   0, 243],
#         [  0,   0, 244],
#         [  0,   0, 244]]], dtype=uint8)

# %%
row_100 = image_array_colored[100,:,:]
print(row_100)
display(Image.fromarray(row_100))
# Out:
# [[152 168 157]
#  [152 168 155]
#  [152 168 157]
#  [152 168 155]
#  [152 168 157]
#  [152 168 155]
#  [151 167 156]
#  [151 167 154]
#  [152 168 157]
#  [152 168 155]
#  [152 168 157]
#  [151 167 154]
#  [151 167 156]
#  [151 167 154]
#  [151 167 156]
#  [150 166 155]
#  [153 169 159]
#  [153 169 159]
#  [154 170 159]
#  [155 171 158]
#  [156 173 157]
#  [157 174 158]
#  [158 175 157]
#  [158 175 157]
#  [158 175 157]
#  [160 177 159]
#  [163 180 164]
#  [165 182 166]
#  [166 182 169]
#  [166 182 171]
#  [165 181 170]
#  [165 181 171]
#  [173 191 179]
#  [156 174 158]
#  [168 191 163]
#  [171 191 156]
#  [118 133  92]
#  [ 77  78  36]
#  [ 99  77  38]
#  [137  92  61]
#  [167  94  75]
#  [114  20  10]
#  [144  32  30]
#  [193  73  74]
#  [186  66  65]
#  [160  45  38]
#  [136  28  16]
#  [161  50  39]
#  [194  72  69]
#  [153  27  28]
#  [131   5   6]
#  [131   5   6]
#  [177  51  52]
#  [168  42  43]
#  [171  45  46]
#  [171  45  46]
#  [143  17  18]
#  [144  18  19]
#  [167  39  40]
#  [176  48  49]
#  [166  38  39]
#  [158  30  31]
#  [146  18  19]
#  [135   5   7]
#  [133   0   5]
#  [149  14  20]
#  [144  11  14]
#  [156  26  28]
#  [156  26  28]
#  [144  16  17]
#  [153  25  24]
#  [144  14  14]
#  [160  30  28]
#  [148  16  14]
#  [158  24  23]
#  [158  22  22]
#  [159  21  19]
#  [160  20  19]
#  [155  11  11]
#  [162  27  24]
#  [138  16  11]
#  [131  16   9]
#  [137  20  13]
#  [150  28  23]
#  [154  29  25]
#  [149  21  18]
#  [149  17  15]
#  [153  19  18]
#  [182  44  44]
#  [152  12  13]
#  [138   0   0]
#  [155  15  16]
#  [175  35  36]
#  [177  37  38]
#  [159  19  20]
#  [142   0   0]
#  [163  15  15]
#  [163  15  15]
#  [174  30  29]
#  [166  27  24]
#  [141   8   3]
#  [161  34  27]
#  [220  96  88]
#  [255 133 125]
#  [235 108 101]
#  [209  76  71]
#  [246 104 102]
#  [238  88  89]
#  [188  27  32]
#  [200  31  38]
#  [212  35  45]
#  [182   6  16]
#  [155   0   0]
#  [227  81  81]
#  [255 144 136]
#  [255 156 146]
#  [255 146 138]
#  [255 139 132]
#  [188  59  53]
#  [203  82  73]
#  [211 108  93]
#  [255 157 142]
#  [233 119 108]
#  [203  74  68]
#  [200  52  52]
#  [202  49  51]
#  [220  78  76]
#  [212 103 100]
#  [201 146 143]
#  [171 147 143]
#  [167 154 148]
#  [165 162 153]
#  [153 163 154]
#  [152 169 159]
#  [150 171 162]
#  [137 163 152]
#  [143 166 158]
#  [142 165 155]
#  [143 163 154]
#  [142 162 151]
#  [141 163 151]
#  [140 164 150]
#  [140 164 150]
#  [138 165 150]
#  [139 166 151]
#  [139 166 149]
#  [139 166 151]
#  [138 165 148]
#  [138 165 150]
#  [137 164 147]
#  [137 164 149]
#  [137 164 147]
#  [138 165 150]
#  [138 165 148]
#  [139 166 151]
#  [140 167 150]
#  [142 169 154]
#  [143 170 153]
#  [144 171 156]
#  [145 172 157]
#  [144 171 156]
#  [144 171 156]
#  [145 172 157]
#  [146 173 158]
#  [147 174 159]
#  [148 175 160]
#  [148 175 160]
#  [149 176 161]
#  [150 177 162]
#  [149 176 161]
#  [149 176 161]
#  [148 175 160]
#  [148 175 160]
#  [149 176 161]
#  [150 177 162]
#  [151 178 163]
#  [153 177 164]
#  [153 176 166]
#  [153 176 166]
#  [154 177 167]
#  [154 177 167]
#  [154 177 167]
#  [155 178 168]
#  [155 178 168]
#  [156 179 169]
#  [156 179 169]
#  [157 180 170]
#  [157 180 170]
#  [158 181 171]
#  [159 182 172]
#  [160 183 173]
#  [160 183 173]
#  [158 183 177]
#  [158 183 179]
#  [159 184 180]
#  [159 184 180]
#  [159 184 180]
#  [160 185 181]
#  [160 185 181]
#  [160 185 181]
#  [160 185 181]
#  [160 185 181]
#  [160 185 181]
#  [160 185 181]
#  [160 185 181]
#  [160 185 181]
#  [160 185 181]
#  [160 185 179]
#  [160 186 177]
#  [159 187 175]
#  [159 187 175]
#  [159 187 175]
#  [159 187 175]
#  [159 187 175]
#  [159 187 175]
#  [159 187 175]
#  [158 186 174]
#  [158 186 174]
#  [157 185 173]
#  [157 185 173]
#  [156 184 172]
#  [156 184 172]
#  [156 184 172]
#  [156 184 172]
#  [154 185 170]
#  [154 185 170]
#  [154 185 170]
#  [154 185 170]
#  [154 185 170]
#  [154 185 170]
#  [154 185 170]
#  [154 185 170]
#  [153 184 169]
#  [153 184 169]
#  [153 184 169]
#  [153 184 169]
#  [153 184 169]
#  [153 184 169]]
# <PIL.Image.Image image mode=L size=3x238>

# %%
left =100
upper = 50
right = 200
lower = 150
cropped_image = image_colored . crop ((left, upper, right, lower))
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
git add .
# Out:
#   File "/tmp/ipython-input-375/2022332482.py", line 1
#     git add .
#         ^
# SyntaxError: invalid syntax
